# %%
from pyspark.sql import SparkSession
spark=SparkSession(sc)

# %%
df1 =spark.read.option("sep", "\t").csv("/BD_Project2/normal_1/airsim_rec.tsv",inferSchema=True)

# %%
#for spark to read the dataset and to create dataframes. 
df2 =spark.read.option("sep", "\t").csv("/BD_Project2/normal_2/airsim_rec.tsv",inferSchema=True)
df3 =spark.read.option("sep", "\t").csv("/BD_Project2/normal_3/airsim_rec.tsv",inferSchema=True)
df4 =spark.read.option("sep", "\t").csv("/BD_Project2/normal_4/airsim_rec.tsv",inferSchema=True)
df5 =spark.read.option("sep", "\t").csv("/BD_Project2/normal_5/airsim_rec.tsv",inferSchema=True)
df6 =spark.read.option("sep", "\t").csv("/BD_Project2/normal_6/airsim_rec.tsv",inferSchema=True)
df7 =spark.read.option("sep", "\t").csv("/BD_Project2/swerve_1/airsim_rec.txt",inferSchema=True)
df8 =spark.read.option("sep", "\t").csv("/BD_Project2/swerve_2/airsim_rec.txt",inferSchema=True)
df9 =spark.read.option("sep", "\t").csv("/BD_Project2/swerve_3/airsim_rec.txt",inferSchema=True)

# %%
df1 = df1.toPandas()

# %%
df2 = df2.toPandas()

# %%
df3 = df3.toPandas()

# %%
df4 = df4.toPandas()

# %%
df5 = df5.toPandas()

# %%
df6 = df6.toPandas()

# %%
df7 = df7.toPandas()

# %%
df8 = df8.toPandas()

# %%
df9 = df9.toPandas()

# %%
df1
# Out:
#             _c0           _c1       _c2        _c3       _c4   _c5  \
# 0     Timestamp  Speed (kmph)  Throttle   Steering     Brake  Gear
# 1      93683464             0  0.000000   0.000000  0.000000     N
# 2      93689595             0  0.000000   0.000000  0.000000     N
# 3      93689624             0  0.000000  -0.035522  0.000000     N
# 4      93689624             0  0.000000  -0.035522  0.000000     N
# ...         ...           ...       ...        ...       ...   ...
# 6404   94009723             2  1.000000   0.236549  0.000000     3
# 6405   94009771             2  1.000000   0.236549  0.000000     3
# 6406   94009795             2  1.000000   0.236549  0.000000     3
# 6407   94009843             2  1.000000   0.236549  0.000000     3
# 6408   94009915             2  1.000000   0.236549  0.000000     3
#
#                _c6
# 0        ImageName
# 1        img_0.png
# 2        img_1.png
# 3        img_2.png
# 4        img_3.png
# ...            ...
# ...

# %%
df9
# Out:
#             _c0           _c1       _c2       _c3       _c4   _c5  \
# 0     Timestamp  Speed (kmph)  Throttle  Steering     Brake  Gear
# 1     357671273             0  0.000000  0.015880  0.000000     1
# 2     357671309             0  0.000000  0.015880  0.000000     1
# 3     357671357             0  0.000000  0.015880  0.000000     1
# 4     357671405             0  0.000000  0.015880  0.000000     1
# ...         ...           ...       ...       ...       ...   ...
# 3363  357839439            20  0.564706  0.113295  0.000000     1
# 3364  357839487            20  0.580392  0.089450  0.000000     1
# 3365  357839535            20  0.564706  0.053641  0.000000     1
# 3366  357839559            20  0.564706  0.037731  0.000000     1
# 3367  357839559            20  0.564706  0.037731  0.000000     1
#
#                _c6
# 0        ImageName
# 1        img_0.png
# 2        img_1.png
# 3        img_2.png
# 4        img_3.png
# ...            ...
# 3363  img_3362.png
# ...

# %%
import pandas as pd
frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9]
df = pd.concat(frames)

# %%
df
# Out:
#             _c0           _c1       _c2        _c3       _c4   _c5  \
# 0     Timestamp  Speed (kmph)  Throttle   Steering     Brake  Gear
# 1      93683464             0  0.000000   0.000000  0.000000     N
# 2      93689595             0  0.000000   0.000000  0.000000     N
# 3      93689624             0  0.000000  -0.035522  0.000000     N
# 4      93689624             0  0.000000  -0.035522  0.000000     N
# ...         ...           ...       ...        ...       ...   ...
# 3363  357839439            20  0.564706   0.113295  0.000000     1
# 3364  357839487            20  0.580392   0.089450  0.000000     1
# 3365  357839535            20  0.564706   0.053641  0.000000     1
# 3366  357839559            20  0.564706   0.037731  0.000000     1
# 3367  357839559            20  0.564706   0.037731  0.000000     1
#
#                _c6
# 0        ImageName
# 1        img_0.png
# 2        img_1.png
# 3        img_2.png
# 4        img_3.png
# ...            ...
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
sample_image = Image.open(img_0.png)
plt.title('Sample Image')
plt.imshow(sample_image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d9784f6056c7> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 from PIL import Image, ImageDraw
# ----> 3 sample_image = Image.open(img_0.png)
#       4 plt.title('Sample Image')
#       5 plt.imshow(sample_image)
#
# NameError: name 'img_0' is not defined

# %%
df['_c6'][2]
# Out:
# 2    img_1.png
# 2    img_1.png
# 2    img_1.png
# 2    img_1.png
# 2    img_1.png
# 2    img_1.png
# 2    img_1.png
# 2    img_1.png
# 2    img_1.png
# Name: _c6, dtype: object

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
sample_image = Image.open(df['_c6'][2])
plt.title('Sample Image')
